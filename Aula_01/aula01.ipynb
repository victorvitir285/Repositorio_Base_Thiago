# %% [markdown]
# ## Aula 01 - Intermediário

# %% [markdown]
#  crição de arquivo

# %%
# criar arquivo

open('cidades','x')
# Out:
# <_io.TextIOWrapper name='cidades' mode='x' encoding='cp1252'>

# %%
escrever = open('cidades.txt','w')
escrever.write('SP; Barueri; R$ 5.800,00')
# Out:
# 24

# %%
escrever = open('cidades.txt','w')
escrever.write('MG; Caratinga; R$ 75. 800,00\n')
escrever.write('RJ; Penha; R$ 10. 800,00\n')
escrever.write('BA; Salvador; R$ 800,00\n')
# Out:
# 24

# %%
addCidades = [

'SP; SANTANA DE PARNAIBA; R$ 80.000,00',
'BA; XIQUE XIQUE; R$ 75.000,00',
'PI; TERESINA; R$ 78.000,00',
'RJ; PENHA; R$ 30.000.00',
'DF; BRASILIA R$ 730.00',
'SP; SANTANA DE PARNAIBA; R$ 80.000,00',
'BA; XIQUE XIQUE; R$ 75.000,00',
'PI; TERESINA; R$ 78.000,00',
'RJ; PENHA; R$ 30.000.00',
'DF; BRASILIA R$ 730.00',


addLista = open('cidades.txt','a')
addlista.writelines(addCidades)

]
# Out:
#   Cell In[23], line 7
#     addLista = open('cidades.txt','a')
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
ler = open('cidades.txt','r')
dados = ler.read()
ler.close()

print(dados)
# Out:
# MG; Caratinga; R$ 75. 800,00
# RJ; Penha; R$ 10. 800,00
# BA; Salvador; R$ 800,00
